# %%
# !pip install ibm-watson
# Out:
# ...
#      |████████████████████████████████| 382 kB 862 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 198 kB 10.0 MB/s eta 0:00:01
# ...
#   Created wheel for ibm-watson: filename=ibm_watson-5.1.0-py3-none-any.whl size=375438 sha256=67aef0dcba69daa36f4e762a9964239006d361cd084f0a084b7ff47a7607d879
#   Stored in directory: /root/.cache/pip/wheels/c1/40/da/ba44de639af32759a5755cb79afedf309104b13fea09bbb5fc
# ...
#   Created wheel for ibm-cloud-sdk-core: filename=ibm_cloud_sdk_core-3.10.0-py3-none-any.whl size=60913 sha256=770c3b1824897761ee700b3bd984041a614dec50452e9a009099967156a9d68a
#   Stored in directory: /root/.cache/pip/wheels/09/6e/48/aa3801c63bbc5914ece2c66a6131925ca99a50d0a16355c8b5
# Successfully built ibm-watson ibm-cloud-sdk-core
# ...
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 0.57.0
#     Uninstalling websocket-client-0.57.0:
#       Successfully uninstalled websocket-client-0.57.0
# ...

# %%
from ibm_watson import PersonalityInsightsV3
from datetime import date

v = str(date.today())
api_key = "fill me in"

# %%
try:
    personality_insights_service = PersonalityInsightsV3(version=v)
except Exception as e:
    print(e)
# Out:
# ...
# authenticator must be provided

# %%
# !wget https://raw.githubusercontent.com/PacktPublishing/Machine-Learning-for-Cybersecurity-Cookbook/master/Chapter04/Personality%20Analysis/ElonMuskTweets.txt
# Out:
# --2021-05-15 04:58:22--  https://raw.githubusercontent.com/PacktPublishing/Machine-Learning-for-Cybersecurity-Cookbook/master/Chapter04/Personality%20Analysis/ElonMuskTweets.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17575 (17K) [text/plain]
# Saving to: ‘ElonMuskTweets.txt’
#
# ElonMuskTweets.txt  100%[===================>]  17.16K  --.-KB/s    in 0s
#
# 2021-05-15 04:58:22 (56.4 MB/s) - ‘ElonMuskTweets.txt’ saved [17575/17575]

# %%
tweets_file = "ElonMuskTweets.txt"

# %%
try:
    with open(tweets_file) as input_file:
        profile = personality_insights_sevice.profile(
            input_file.read(),
            "application/json",
            raw_scores=False,
            consumption_preferences=True
        ).get_result()
except:
    pass

# %%
try:
    import json
    print(json.dumps(profile, indent=2))
except:
    pass
