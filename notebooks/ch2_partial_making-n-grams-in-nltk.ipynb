# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.7/site-packages (3.2.4)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from nltk) (1.15.0)

# %%
import collections
from nltk import ngrams

# %%
import pandas as pd

data = pd.read_csv("../input/first-gop-debate-twitter-sentiment/Sentiment.csv")

all_tweets = []
for i in data['text']:
    all_tweets.append(str(i))

# %%
tweets = "".join(all_tweets)

# %%
len(tweets)
# Out:
# 1587793

# %%
Ngrams = ngrams(tweets, 4)

# %%
extracted_ngrams = collections.Counter(list(Ngrams))

# %%
print(extracted_ngrams.most_common(10))
# Out:
# [(('e', 'b', 'a', 't'), 16091), (('b', 'a', 't', 'e'), 15922), (('#', 'G', 'O', 'P'), 14489), (('D', 'e', 'b', 'a'), 13956), (('G', 'O', 'P', 'D'), 13391), ((' ', '#', 'G', 'O'), 13352), (('O', 'P', 'D', 'e'), 13234), (('P', 'D', 'e', 'b'), 13199), ((' ', 't', 'h', 'e'), 9941), (('t', 'h', 'e', ' '), 7843)]

# %% [markdown]
# Lets put K1 = 1000 most frequent N-grams into a list

# %%
K1 = 1000

K1_most_frequent_Ngrams = extracted_ngrams.most_common(K1)
K1_most_frequent_Ngrams_list = [x[0] for x in K1_most_frequent_Ngrams]

# %%
K1_most_frequent_Ngrams_list
# Out:
# [('e', 'b', 'a', 't'),
#  ('b', 'a', 't', 'e'),
#  ('#', 'G', 'O', 'P'),
#  ('D', 'e', 'b', 'a'),
#  ('G', 'O', 'P', 'D'),
#  (' ', '#', 'G', 'O'),
#  ('O', 'P', 'D', 'e'),
#  ('P', 'D', 'e', 'b'),
#  (' ', 't', 'h', 'e'),
#  ('t', 'h', 'e', ' '),
#  ('R', 'T', ' ', '@'),
#  ('a', 't', 'e', ' '),
#  ('a', 't', 'e', 's'),
#  ('i', 'n', 'g', ' '),
#  (' ', 't', 'o', ' '),
#  ('h', 't', 't', 'p'),
#  (' ', 'h', 't', 't'),
#  (':', '/', '/', 't'),
#  ('/', '/', 't', '.'),
#  ('/', 't', '.', 'c'),
#  ('t', '.', 'c', 'o'),
#  ('.', 'c', 'o', '/'),
#  ('r', 'u', 'm', 'p'),
#  (' ', 'o', 'f', ' '),
#  ('a', 'n', 'd', ' '),
#  ('T', 'r', 'u', 'm'),
#  (' ', 'i', 's', ' '),
#  ('t', 't', 'p', ':'),
#  ('t', 'p', ':', '/'),
#  ('p', ':', '/', '/'),
#  ('t', 'e', 's', ' '),
#  (' ', 'a', 'n', 'd'),
#  ('u', 'm', 'p', ' '),
#  ('.', ' ', '#', 'G'),
#  ('e', ' ', '#', 'G'),
#  ('s', 'R', 'T', ' '),
#  ('d', 'e', 'b', 'a'),
#  ('i', 'g', 'h', 't'),
#  ('t', 'e', 's', 'R'),
#  ('t', 'i', 'o', 'n'),
#  ('e', 's', 'R', 'T'),
#  (' ', ' ', '#', 'G'),
#  ('T', ' ', '@', 'R'),
#  ('h', 'a', 't', ' '),
#  ('r', 'l', ':', ' '),
#  (' ', 'y', 'o', 'u'),
#  ('G', 'i', 'r', 'l'),
#  (' ', 'f', 'o', 'r'),
#  ('i', 'r', 'l', ':'),
#  ('u', 'r', 'f', 'e'),
#  ('@', 'R', 'W', 'S'),
#  ('R', 'W', 'S', 'u'),
#  ('W', 'S', 'u', 'r'),
#  ('S', 'u', 'r', 'f'),
#  ('r', 'f', 'e', 'r'),
#  ('f', 'e', 'r', 'G'),
#  ('e', 'r', 'G', 'i'),
#  ('r', 'G', 'i', 'r'),
#  (' ', '@', 'R', 'W'),
#  ('o', 'n', 'a', 'l'),
#  ('h', 'e', ' ', '#'),
#  (' ', 't', 'h', 'i'),
#  (' ', 'i', 'n', ' '),
#  ('e', ' ', 't', 'h'),
#  ('n', 'g', ' ', 't'),
#  ('f', 'o', 'r', ' '),
#  ('t', 'e', ' ', ' '),
#  (' ', 't', 'h', 'a'),
#  ('n', "'", 't', ' '),
#  ('n', 'a', 'l', 'd'),
#  (' ', 'c', 'a', 'n'),
#  ('r', 'e', 'a', 'l'),
#  ('D', 'o', 'n', 'a'),
#  (' ', '🇺', '🇸', ' '),
#  ('o', 'u', 't', ' '),
#  ('h', 'i', 's', ' '),
#  ('…', 'R', 'T', ' '),
#  (' ', 'T', 'r', 'u'),
#  ('n', ' ', 't', 'h'),
#  (' ', 'o', 'n', ' '),
#  ('🇺', '🇸', ' ', '#'),
#  ('🇸', ' ', '#', 'G'),
#  ('t', ' ', 't', 'h'),
#  ('N', 'e', 'w', 's'),
#  ('e', ' ', ' ', '#'),
#  ('l', 'l', 'y', ' '),
#  ('t', 'h', 'a', 't'),
#  ('y', 'o', 'u', ' '),
#  ('n', 'i', 'g', 'h'),
#  ('e', 'w', 's', ' '),
#  ('s', ' ', 't', 'h'),
#  ('f', ' ', 't', 'h'),
#  ('o', 'u', 'l', 'd'),
#  ('a', 'n', 'd', 'i'),
#  ('e', 'R', 'T', ' '),
#  (' ', 'a', 'b', 'o'),
#  ('t', 'i', 'n', 'g'),
#  ('a', 'l', 'd', 'T'),
#  ('d', 'T', 'r', 'u'),
#  ('l', 'd', 'T', 'r'),
#  ('d', 'a', 't', 'e'),
#  ('n', 'd', 'i', 'd'),
#  ('d', 'i', 'd', 'a'),
#  ('i', 'd', 'a', 't'),
#  ('t', 'h', 'i', 'n'),
#  (' ', 'w', 'a', 's'),
#  ('t', 'e', ' ', '#'),
#  ('b', 'o', 'u', 't'),
#  ('c', 'a', 'n', 'd'),
#  ('o', 'f', ' ', 't'),
#  (' ', 'n', 'o', 't'),
#  (' ', 'i', 't', ' '),
#  ('a', 'b', 'o', 'u'),
#  ('g', ' ', 't', 'h'),
#  ('i', 'c', 'a', 'n'),
#  ('u', 'l', 'd', ' '),
#  ('a', 't', 'e', 'R'),
#  ('.', ' ', '🇺', '🇸'),
#  ('e', 'a', 'l', 'D'),
#  ('l', 'D', 'o', 'n'),
#  ('a', 'l', 'D', 'o'),
#  ('w', 'a', 's', ' '),
#  ('@', 'r', 'e', 'a'),
#  ('t', 'e', 'R', 'T'),
#  ('h', 'i', 'n', 'g'),
#  ('t', 'h', 'e', 'r'),
#  ('&', 'a', 'm', 'p'),
#  ('a', 'm', 'p', ';'),
#  ('h', 'r', 'i', 's'),
#  ('c', 'a', 'n', ' '),
#  ('e', 'd', ' ', 't'),
#  ('k', 'i', 'n', 'g'),
#  (' ', '&', 'a', 'm'),
#  ('m', 'p', ';', ' '),
#  ('C', 'h', 'r', 'i'),
#  ('n', 'o', 't', ' '),
#  (' ', 'f', 'r', 'o'),
#  ('F', 'o', 'x', ' '),
#  ('a', 's', 't', ' '),
#  ('T', 'h', 'e', ' '),
#  (' ', 'F', 'o', 'x'),
#  ('o', 'n', 'e', ' '),
#  ('d', ' ', 't', 'h'),
#  ('a', 'v', 'e', ' '),
#  (' ', '@', 'r', 'e'),
#  ('t', 'h', 'i', 's'),
#  ('e', 'l', 'l', 'y'),
#  ('g', 'h', 't', ' '),
#  ('e', ' ', 't', 'o'),
#  (' ', 'd', 'e', 'b'),
#  ('e', 'g', 'y', 'n'),
#  ('f', 'r', 'o', 'm'),
#  ('t', 'e', 'r', ' '),
#  ('e', ' ', 'h', 't'),
#  ('d', ' ', 't', 'o'),
#  (' ', 'n', 'i', 'g'),
#  (' ', 'h', 'a', 'v'),
#  ('a', 'r', 'e', ' '),
#  ('t', 't', 'p', 's'),
#  ('i', 'o', 'n', ' '),
#  ('t', 'p', 's', ':'),
#  (' ', 'T', 'h', 'e'),
#  ('p', 's', ':', '/'),
#  ('t', 'e', ' ', 'h'),
#  ('s', ':', '/', '/'),
#  ('h', 'a', 'v', 'e'),
#  ('r', 'o', 'm', ' '),
#  ('s', 't', ' ', 'n'),
#  (' ', 'a', 't', ' '),
#  ('t', "'", 's', ' '),
#  (' ', 'N', 'e', 'w'),
#  ('e', 's', 't', 'i'),
#  ('r', ' ', 't', 'h'),
#  ('u', 's', 't', ' '),
#  ('h', 'e', 'r', ' '),
#  ('t', ' ', 'n', 'i'),
#  ('G', 'O', 'P', 'd'),
#  ('i', 'k', 'e', ' '),
#  ('O', 'P', 'd', 'e'),
#  ('i', 'n', ' ', 't'),
#  ('l', 'a', 's', 't'),
#  ('P', 'd', 'e', 'b'),
#  ('e', ' ', 'o', 'f'),
#  ('e', 'n', 't', ' '),
#  ('m', 'e', 'n', 't'),
#  ('s', ' ', 't', 'o'),
#  (' ', 'l', 'a', 's'),
#  (' ', 'b', 'e', ' '),
#  ('s', ' ', 'a', 'n'),
#  ('a', 'l', 'l', ' '),
#  ('e', 'r', 'e', ' '),
#  (' ', 'a', 'r', 'e'),
#  ('u', 'e', 's', 't'),
#  ('i', 'l', 'l', ' '),
#  ('w', 'i', 't', 'h'),
#  ('s', 'i', 'd', 'e'),
#  ('l', 'i', 'k', 'e'),
#  ('a', 'l', 'l', 'y'),
#  ('s', 't', 'i', 'o'),
#  ('i', 'd', 'e', 'n'),
#  ('d', 'e', 'n', 't'),
#  (' ', 'l', 'i', 'k'),
#  ('e', 'r', 'i', 'c'),
#  ('e', ' ', 'c', 'a'),
#  (' ', 'w', 'i', 't'),
#  ('s', ' ', '#', 'G'),
#  ('h', 'e', 'y', ' '),
#  ('C', 'r', 'u', 'z'),
#  (' ', 'r', 'e', 'a'),
#  ('?', ' ', '#', 'G'),
#  ('i', 't', 'h', ' '),
#  (' ', 'q', 'u', 'e'),
#  (' ', 's', 'h', 'o'),
#  ('q', 'u', 'e', 's'),
#  ('o', 'u', 'r', ' '),
#  ('o', 'n', "'", 't'),
#  ('e', ' ', 'w', 'a'),
#  ('t', 'e', 'd', ' '),
#  ('n', 'g', ' ', 'a'),
#  ('r', 's', 'o', 'n'),
#  ('b', 'u', 't', ' '),
#  ('B', 'u', 's', 'h'),
#  ('t', ' ', 't', 'o'),
#  ('a', 't', 'e', '.'),
#  (' ', 'b', 'u', 't'),
#  ('t', 'h', 'e', 'y'),
#  ('h', 'e', 'r', 'e'),
#  ('r', 'e', 's', 'i'),
#  ('a', 't', 'c', 'h'),
#  ('e', 's', 'i', 'd'),
#  (' ', 'd', 'o', 'n'),
#  ('G', 'O', 'P', ' '),
#  ('\n', '#', 'G', 'O'),
#  (' ', 's', 't', 'a'),
#  ('j', 'u', 's', 't'),
#  (' ', 'g', 'e', 't'),
#  ('h', 'e', ' ', 'c'),
#  ('m', 'e', 'r', 'i'),
#  ('r', 'i', 'c', 'a'),
#  ('i', 'o', 'n', 's'),
#  (':', ' ', 'T', 'h'),
#  ('s', ' ', 'i', 's'),
#  ('s', ' ', 'a', ' '),
#  ('r', 'i', 'n', 'g'),
#  ('g', ' ', 't', 'o'),
#  ('e', 'r', 's', ' '),
#  ('a', 't', 'i', 'o'),
#  (' ', 'w', 'h', 'o'),
#  (' ', 'j', 'u', 's'),
#  ('e', 's', ' ', 'a'),
#  ('u', 'b', 'l', 'i'),
#  ('e', 'v', 'e', 'r'),
#  ('u', 's', 'h', ' '),
#  ('e', 'p', 'u', 'b'),
#  ('o', 'n', ' ', 't'),
#  ('b', 'l', 'i', 'c'),
#  ('h', 'e', 'n', ' '),
#  ('s', ' ', 'n', 'o'),
#  ('p', 'u', 'b', 'l'),
#  ('e', 'o', 'p', 'l'),
#  ('o', 'p', 'l', 'e'),
#  ('h', 'e', ' ', 'm'),
#  (' ', 'c', 'o', 'm'),
#  ('A', 'm', 'e', 'r'),
#  ('p', 'l', 'e', ' '),
#  ('v', 'e', 'r', 'y'),
#  (' ', 'w', 'h', 'e'),
#  (' ', 'm', 'e', ' '),
#  ('e', 's', ' ', '#'),
#  ('h', 'i', 'n', 'k'),
#  ('a', 'n', 'c', 'e'),
#  (' ', 'c', 'o', 'n'),
#  ('m', 'e', 'g', 'y'),
#  ('k', 'e', 'l', 'l'),
#  ('t', 'o', ' ', 't'),
#  (' ', 'C', 'h', 'r'),
#  (' ', 'h', 'e', ' '),
#  ('l', 'i', 'c', 'a'),
#  ('t', ' ', 'o', 'f'),
#  ('g', 'y', 'n', 'k'),
#  ('y', 'n', 'k', 'e'),
#  ('n', 'k', 'e', 'l'),
#  ('t', 'e', '.', ' '),
#  ('o', ' ', 't', 'h'),
#  ('p', 'e', 'o', 'p'),
#  ('r', 'u', 'z', ' '),
#  ('@', 'm', 'e', 'g'),
#  (' ', 'a', 'l', 'l'),
#  (' ', 'p', 'e', 'o'),
#  ('e', ' ', 'i', 'n'),
#  ('h', 'o', 'w', ' '),
#  ('l', ':', ' ', 'I'),
#  (' ', 'W', 'a', 'l'),
#  ('R', 'e', 'p', 'u'),
#  ('x', ' ', 'N', 'e'),
#  ('o', 'x', ' ', 'N'),
#  ('p', 'o', 'l', 'i'),
#  (' ', 'h', 'a', 's'),
#  ('u', 't', ' ', 't'),
#  (' ', 'p', 'r', 'o'),
#  ('w', 'h', 'a', 't'),
#  ('o', 'r', 'e', ' '),
#  ('t', 't', 'e', 'r'),
#  (' ', 'd', 'i', 'd'),
#  ('l', 'i', 't', 'i'),
#  ('d', 'o', 'n', "'"),
#  ('a', 't', ' ', 't'),
#  (' ', 'a', 'n', 'y'),
#  ('i', 't', 'i', 'c'),
#  ('x', 'N', 'e', 'w'),
#  ('n', 'c', 'e', ' '),
#  ('o', 'l', 'i', 't'),
#  ('h', 'o', 'u', 'l'),
#  ('o', 'x', 'N', 'e'),
#  ('w', 'h', 'o', ' '),
#  ('k', ' ', 't', 'h'),
#  ('w', 'a', 't', 'c'),
#  ('s', '.', ' ', '#'),
#  ('F', 'o', 'x', 'N'),
#  ('s', 'h', 'o', 'u'),
#  (' ', 'w', 'h', 'a'),
#  (' ', 'w', 'a', 't'),
#  (' ', 'p', 'o', 'l'),
#  ('u', 'b', 'i', 'o'),
#  ('v', 'e', 'r', ' '),
#  ('a', 'r', 's', 'o'),
#  ('h', 'a', 's', ' '),
#  ('h', 'e', ' ', 's'),
#  ('a', 'n', 't', ' '),
#  ('.', '.', '.', ' '),
#  (' ', 'o', 'u', 't'),
#  (' ', 'J', 'e', 'b'),
#  (' ', 'e', 'v', 'e'),
#  ('i', 's', ' ', 't'),
#  ('C', 'a', 'r', 's'),
#  (' ', 'A', 'm', 'e'),
#  (' ', 'B', 'u', 's'),
#  ('t', 'o', ' ', 's'),
#  ('e', 'r', ' ', 't'),
#  ('o', 't', 'h', 'e'),
#  (' ', 's', 'e', 'e'),
#  (' ', '@', 'm', 'e'),
#  ('J', 'e', 'b', ' '),
#  ('r', 'i', 's', 't'),
#  ('d', ' ', 'T', 'r'),
#  (' ', 'w', 'e', ' '),
#  ('e', 's', '.', ' '),
#  ('d', 'o', 'e', 's'),
#  ('e', ' ', 'a', ' '),
#  ('t', 'h', 'e', 'i'),
#  ('o', 'm', 'e', 'n'),
#  (' ', 'd', 'o', 'e'),
#  (' ', 'w', 'a', 'n'),
#  ('h', 'e', 'i', 'r'),
#  ('e', ' ', 'a', 'n'),
#  ('s', 'i', 'n', 'g'),
#  ('e', 'i', 'r', ' '),
#  ('2', '0', '1', '6'),
#  ('y', 'i', 'n', 'g'),
#  ('a', 'c', 'e', ' '),
#  ('o', 'v', 'e', 'r'),
#  (' ', 'w', 'o', 'u'),
#  ('w', 'o', 'u', 'l'),
#  ('i', 'n', 'k', ' '),
#  ('i', 's', 't', 'i'),
#  (' ', 'R', 'e', 'p'),
#  ('n', 'i', 'n', 'g'),
#  ('s', ' ', 'h', 't'),
#  ('n', 'o', 'w', ' '),
#  (' ', 'Y', 'o', 'u'),
#  (' ', 'm', 'o', 'r'),
#  ('w', 'a', 'n', 't'),
#  (' ', 'a', 's', ' '),
#  (' ', 'b', 'y', ' '),
#  ('t', 'o', ' ', 'b'),
#  (' ', 'u', 'p', ' '),
#  ('r', 'a', 't', 'i'),
#  (' ', 'm', 'y', ' '),
#  (' ', 'I', ' ', 'w'),
#  ('s', 'e', 'd', ' '),
#  ('n', 'd', ' ', 't'),
#  ('m', 'o', 'r', 'e'),
#  ('n', 'e', 'e', 'd'),
#  (' ', 'n', 'e', 'e'),
#  ('e', 'n', 't', 'i'),
#  ('r', 'i', 'g', 'h'),
#  ('t', 'e', ' ', 'w'),
#  (':', ' ', 'I', ' '),
#  ('r', 'e', ' ', 't'),
#  ('m', 'e', ' ', 'o'),
#  ('s', 'o', 'n', ' '),
#  (' ', 's', 'a', 'y'),
#  ('l', 'a', 'c', 'e'),
#  ('t', ' ', '#', 'G'),
#  ('P', 'r', 'e', 's'),
#  ('s', ' ', 'i', 'n'),
#  ('e', 's', ' ', 'h'),
#  ('e', 's', 't', ' '),
#  ('e', ' ', 'o', 'n'),
#  ('a', 'r', 'y', ' '),
#  (' ', 'o', 'n', 'e'),
#  ('Y', 'o', 'u', ' '),
#  ('g', 'e', 't', ' '),
#  (' ', 'w', 'i', 'l'),
#  ('a', 'c', 'k', ' '),
#  ('H', 'u', 'c', 'k'),
#  ('e', 'a', 'r', ' '),
#  (' ', 'P', 'r', 'e'),
#  ('w', 'i', 'l', 'l'),
#  (' ', 'C', 'a', 'r'),
#  ('o', 'r', ' ', 't'),
#  ('h', 'e', ' ', 'p'),
#  ('T', ' ', '@', 'm'),
#  ('e', 'r', 'y', ' '),
#  (' ', 'h', 'i', 'm'),
#  ('t', ' ', 'w', 'a'),
#  (' ', 'm', 'a', 'k'),
#  ('n', 'd', 'e', 'r'),
#  ('.', 'R', 'T', ' '),
#  (' ', 'h', 'e', 'a'),
#  ('o', 'u', 'g', 'h'),
#  ('R', 'u', 'b', 'i'),
#  ('e', '.', ' ', '#'),
#  (' ', 'h', 'i', 's'),
#  (' ', 'w', 'o', 'r'),
#  ('I', "'", 'm', ' '),
#  (' ', 'a', 's', 'k'),
#  ('e', ' ', 'i', 's'),
#  (' ', 'h', 'o', 'w'),
#  ('v', 'e', ' ', 't'),
#  ('e', ' ', 'w', 'h'),
#  ('T', ' ', '@', 'S'),
#  ('@', 'F', 'o', 'x'),
#  ('u', 'c', 'k', 'a'),
#  ('c', 'k', 'a', 'b'),
#  ('a', 'b', 'e', 'e'),
#  ('e', 'e', 'd', ' '),
#  ('k', 'a', 'b', 'e'),
#  ('o', 's', 'e', ' '),
#  (' ', 'd', 'i', 's'),
#  (' ', 'p', 'i', 'c'),
#  ('d', ' ', 'o', 'f'),
#  (' ', 'G', 'O', 'P'),
#  ('h', 'e', ' ', 'f'),
#  ('n', ' ', '#', 'G'),
#  (',', ' ', 'a', 'n'),
#  ('r', 'i', 's', ' '),
#  ('t', 'i', 'm', 'e'),
#  (' ', 'o', 'r', ' '),
#  ('a', 'l', 'd', ' '),
#  ('t', 'a', 'l', 'k'),
#  ('w', 'h', 'e', 'n'),
#  ('h', 'e', ' ', 'n'),
#  ('a', 'k', 'e', ' '),
#  ('e', "'", 's', ' '),
#  ('i', 'a', 'l', ' '),
#  (' ', 'w', 'o', 'm'),
#  ('a', 's', ' ', 'a'),
#  ('a', 'r', 'l', 'y'),
#  ('e', 'n', 'c', 'e'),
#  ('e', ' ', 'm', 'o'),
#  ('i', 'l', 'l', 'a'),
#  ('i', 's', ' ', 'a'),
#  ('a', 'n', 's', ' '),
#  ('l', 'l', 'a', 'r'),
#  ('l', 'a', 'r', 'y'),
#  ('h', 'e', ' ', 'w'),
#  (' ', 't', 'a', 'l'),
#  (' ', 'C', 'r', 'u'),
#  ('e', ' ', 'r', 'e'),
#  ('e', 's', 'e', ' '),
#  ('i', 'n', 'g', '.'),
#  ('e', 'r', ':', ' '),
#  (' ', 'p', 'r', 'e'),
#  ('s', 'n', "'", 't'),
#  ('i', 'n', 't', 'o'),
#  ('h', 'e', 's', 'e'),
#  ('a', 't', 'o', 'r'),
#  ('e', 'd', ' ', 'a'),
#  ('e', ' ', 'n', 'e'),
#  ('W', 'a', 'l', 'l'),
#  ('m', 'a', 'k', 'e'),
#  ('a', 'l', 'l', 'a'),
#  ('t', ' ', 'h', 'a'),
#  (' ', ' ', 'h', 't'),
#  ('H', 'i', 'l', 'l'),
#  (' ', 'D', 'o', 'n'),
#  ('p', 'o', 'r', 't'),
#  ('!', ' ', '#', 'G'),
#  (' ', 's', 'p', 'e'),
#  (' ', 'r', 'i', 'g'),
#  ('i', 'n', 'g', 's'),
#  ('o', 'n', 's', ' '),
#  ('y', ' ', 't', 'h'),
#  (' ', 'i', 'f', ' '),
#  (' ', 'l', 'e', 'a'),
#  ('a', 'l', 'k', 'e'),
#  ('e', 'l', 'l', ' '),
#  ('p', 'o', 's', 'e'),
#  ('i', 'v', 'e', ' '),
#  ('l', 'l', 'a', 'c'),
#  ('y', 'o', 'u', 'r'),
#  ('e', ' ', 'f', 'o'),
#  ('t', 'a', 't', 'e'),
#  ('c', 'h', 'i', 'n'),
#  ('y', 'o', 'n', 'e'),
#  ('n', 't', ' ', 't'),
#  ('o', 'r', 'i', 'n'),
#  ('o', 's', 't', ' '),
#  (' ', 'w', 'o', 'n'),
#  (' ', 'k', 'n', 'o'),
#  ('s', 't', 'i', 'e'),
#  ('P', 'a', 'u', 'l'),
#  ('a', 'n', 'y', ' '),
#  ('p', 'r', 'e', 's'),
#  ('t', 'e', 's', '.'),
#  ('i', 'o', 'u', 's'),
#  (' ', 'd', 'o', ' '),
#  ('k', 'n', 'o', 'w'),
#  ('i', 's', ' ', 'd'),
#  ('t', ' ', 'u', 'p'),
#  ('t', 'h', 'e', 'm'),
#  (' ', '@', 'F', 'o'),
#  (' ', 'c', 'o', 'u'),
#  ('n', 'e', 'd', ' '),
#  ('n', ' ', 't', 'o'),
#  ('s', 'o', 'm', 'e'),
#  ('C', 'a', 'r', 'l'),
#  ('o', 'i', 'n', 'g'),
#  ('l', 'l', ' ', 't'),
#  ('r', 'e', ' ', 'a'),
#  ('#', 'g', 'o', 'p'),
#  ('f', 't', 'e', 'r'),
#  (' ', 't', 'i', 'm'),
#  ('i', 'o', 'r', 'i'),
#  ('r', 'e', 'a', 't'),
#  ('.', ' ', 'h', 't'),
#  ('t', 'h', 'a', 'n'),
#  (' ', 'f', 'a', 'c'),
#  ('e', 'r', ' ', 'a'),
#  ('n', 'l', 'y', ' '),
#  ('t', ' ', 'a', ' '),
#  ('o', 'i', 'n', 't'),
#  ('l', ' ', 't', 'h'),
#  ('n', 'd', 's', ' '),
#  (' ', 'w', 'i', 'n'),
#  ('s', ' ', 'd', 'o'),
#  ('e', 'a', 'l', 'l'),
#  ('e', ' ', 'c', 'o'),
#  ('m', 'e', 'n', ' '),
#  ('0', '1', '6', ' '),
#  (' ', 'G', 'o', 'd'),
#  ('r', 'i', 'n', 'a'),
#  ('a', 's', 'i', 'c'),
#  ('h', 'e', ' ', 'd'),
#  ('t', 'c', 'h', 'i'),
#  ('l', 'k', 'e', 'r'),
#  ('d', 'n', "'", 't'),
#  ('n', 'g', ' ', 'i'),
#  ('o', 'n', ' ', '#'),
#  ('h', 'a', 'n', ' '),
#  ('.', ' ', 'T', 'h'),
#  ('e', ' ', 'R', 'e'),
#  ('F', 'i', 'o', 'r'),
#  ('s', ' ', 'o', 'n'),
#  ('e', 's', 's', ' '),
#  (' ', '#', 'g', 'o'),
#  ('o', 'p', 'd', 'e'),
#  ('p', 'd', 'e', 'b'),
#  (' ', 'I', "'", 'm'),
#  ('h', 'i', 'm', ' '),
#  (' ', 'h', 'e', 'r'),
#  (' ', 's', 'a', 'i'),
#  ('R', 'a', 'n', 'd'),
#  ('W', 'a', 'l', 'k'),
#  ('w', 's', ' ', 'i'),
#  ('c', 'a', 'l', 'l'),
#  ('s', 'a', 'i', 'd'),
#  ('e', ' ', 'h', 'a'),
#  ('K', 'e', 'l', 'l'),
#  ('s', ' ', 'o', 'f'),
#  ('l', ':', ' ', 'F'),
#  ('t', ' ', 'i', 's'),
#  ('l', 'i', 'n', 'g'),
#  ('o', 'n', 'i', 'g'),
#  ('a', 'i', 'r', ' '),
#  ('t', 'o', ' ', 'a'),
#  ('e', ' ', 'b', 'e'),
#  ('c', 'o', 'm', 'e'),
#  ('h', 'e', ' ', 'o'),
#  ('g', 'o', 'p', 'd'),
#  (' ', 'R', 'u', 'b'),
#  ('n', 'g', '.', ' '),
#  ('i', 'c', 'h', ' '),
#  ('o', 'm', 'e', ' '),
#  ('e', ' ', 'w', 'i'),
#  ('o', 'r', ' ', 'a'),
#  ('M', 'e', 'g', 'y'),
#  (' ', 's', 'o', 'm'),
#  ('o', 'o', 'd', ' '),
#  (' ', 'p', 'l', 'a'),
#  ('#', 'T', 'r', 'u'),
#  ('c', 'k', 'i', 'n'),
#  ('a', 'g', 'e', ' '),
#  ('i', 's', ' ', 's'),
#  ('l', 'd', ' ', 'T'),
#  ('i', 'n', 'a', ' '),
#  ('t', 'h', 'e', 's'),
#  (' ', 'r', 'e', 'm'),
#  ('s', ' ', 'i', 't'),
#  ('d', 'e', 'r', ' '),
#  (':', ' ', 'F', 'o'),
#  ('c', 'a', 'n', 's'),
#  ('e', ' ', 'w', 'o'),
#  ('a', 's', 'k', ' '),
#  ('s', 'e', ' ', 't'),
#  ('h', 'e', ' ', 'R'),
#  ('I', ' ', 't', 'h'),
#  ('n', 't', 's', ' '),
#  ('p', 'e', 'a', 'k'),
#  ('e', 't', 's', ' '),
#  ('e', ' ', 'm', 'a'),
#  ('r', ' ', 'a', 'n'),
#  ('s', 'i', 'c', 'h'),
#  ('l', 'y', ' ', 't'),
#  ('e', ' ', 'd', 'e'),
#  ('t', ' ', 'y', 'o'),
#  ('p', 'o', 'i', 'n'),
#  ('l', ':', ' ', 'T'),
#  ('t', '.', ' ', '#'),
#  ('s', ' ', '🇺', '🇸'),
#  ('s', ' ', 'l', 'i'),
#  ('h', 'e', 'a', 'r'),
#  ('d', 'i', 'n', 'g'),
#  ('w', 'o', 'm', 'e'),
#  ("'", 'r', 'e', ' '),
#  (' ', 'n', 'e', 'x'),
#  ('n', 'e', 'x', 't'),
#  ('a', 'k', 'i', 'n'),
#  ('h', 'e', ' ', 'b'),
#  (' ', 'm', 'e', 'n'),
#  ('K', 'a', 's', 'i'),
#  ('w', 'e', 'r', 'e'),
#  (' ', 'I', 't', ' '),
#  ('t', 's', ' ', 't'),
#  (' ', 'D', 'e', 'b'),
#  ('a', 't', 'i', 'n'),
#  (':', ' ', 'W', 'h'),
#  (' ', 'v', 'e', 'r'),
#  ('g', 'h', 't', 's'),
#  ('m', 'o', 's', 't'),
#  ('s', 'p', 'e', 'a'),
#  (' ', 'a', 't', 't'),
#  (' ', 'I', ' ', 't'),
#  ('n', 'g', ' ', 'f'),
#  (' ', 'm', 'a', 'n'),
#  ('t', 'i', 'c', 'a'),
#  ('o', 'n', '.', ' '),
#  ('r', 'm', 'a', 'n'),
#  ('n', 'g', ' ', 'h'),
#  ('i', 's', ' ', 'c'),
#  ('i', 't', 'y', ' '),
#  ('y', ' ', 'd', 'i'),
#  (' ', 'T', 'h', 'a'),
#  ('n', 'g', ' ', 'o'),
#  (' ', 'p', 'e', 'r'),
#  ('a', 's', ' ', 't'),
#  ('p', 'i', 'c', 'k'),
#  ('o', 'c', 'r', 'a'),
#  ('s', ' ', 'W', 'a'),
#  ('t', 'o', ' ', 'p'),
#  ('o', 'n', 'l', 'y'),
#  ('s', ' ', 'a', 'b'),
#  ('c', 'i', 'a', 'l'),
#  ('t', ' ', 'f', 'o'),
#  ('i', 'o', 'n', '.'),
#  (' ', 'a', 'n', ' '),
#  (' ', 't', 'a', 'k'),
#  (' ', 'o', 'n', 'l'),
#  ('t', 'i', 'e', ' '),
#  (' ', 's', 'o', ' '),
#  ('e', 'e', 'n', ' '),
#  ('T', 'h', 'i', 's'),
#  ('s', ' ', 'w', 'h'),
#  (' ', 'w', 'e', 'r'),
#  ('s', ' ', 'd', 'e'),
#  (' ', 'n', 'o', ' '),
#  ('t', 'a', 'k', 'e'),
#  ('o', 'e', 's', ' '),
#  ('i', 's', ' ', 'i'),
#  (' ', '#', 'T', 'r'),
#  (':', ' ', 'T', 'r'),
#  ('e', 'b', ' ', 'B'),
#  ('e', ' ', 'n', 'o'),
#  ('e', 'n', ' ', 't'),
#  (' ', 't', 'o', 'n'),
#  ('d', 'i', 'd', ' '),
#  ('g', 'h', 't', '.'),
#  ('a', 'y', 's', ' '),
#  ('w', 'e', 'e', 't'),
#  ('i', 's', ' ', 'n'),
#  ('a', 'i', 'd', ' '),
#  ('i', 's', ' ', 'W'),
#  (' ', 'o', 't', 'h'),
#  ('t', ' ', 'l', 'i'),
#  (' ', 'o', 'u', 'r'),
#  ('b', ' ', 'B', 'u'),
#  ('s', ' ', 'm', 'e'),
#  ('h', 'e', ' ', 't'),
#  (' ', 'j', 'o', 'b'),
#  ('e', 'm', 'o', 'c'),
#  ('a', 't', ' ', 'a'),
#  ('m', 'o', 'c', 'r'),
#  (' ', 'l', 'o', 'o'),
#  (' ', 'i', 'n', 't'),
#  ('t', 'o', 'n', 'i'),
#  ('n', 'n', 'e', 'r'),
#  ('t', ' ', 'c', 'o'),
#  ('e', ' ', 'l', 'a'),
#  ('t', 'o', 'n', ' '),
#  ('t', 'e', ':', ' '),
#  ('i', 'm', 'e', ' '),
#  ('i', 's', 't', 'e'),
#  ('e', 's', ' ', 't'),
#  ('i', 'e', 's', ' '),
#  ('o', ' ', 'b', 'e'),
#  ('d', ' ', 'a', ' '),
#  ('n', 't', 'o', 'n'),
#  ('n', 't', 'e', 'r'),
#  ('l', ':', ' ', 'W'),
#  ('y', ' ', 'i', 's'),
#  (' ', 'W', 'e', ' '),
#  ('i', 'c', 'a', 'l'),
#  ('s', ' ', 'f', 'o'),
#  ('v', 'e', 'n', ' '),
#  (' ', 'F', 'O', 'X'),
#  ('s', ' ', 'a', 'r'),
#  ('a', 'm', 'e', ' '),
#  ('e', ' ', 's', 'o'),
#  ('e', 'a', 't', ' '),
#  ('s', 'e', 'r', 'v'),
#  ('x', ' ', 'i', 's'),
#  ('e', ' ', 's', 'a'),
#  (' ', 'm', 'o', 's'),
#  ('o', 'e', 's', 'n'),
#  ('o', 'x', ' ', 'i'),
#  ('g', 'h', 't', "'"),
#  ('l', 'a', 'c', 'k'),
#  ('l', 'o', 'o', 'k'),
#  (' ', 'e', 'l', 'e'),
#  ('n', 'i', 't', 'e'),
#  ('F', 'O', 'X', ' '),
#  (':', ' ', '#', 'G'),
#  (' ', 'e', 'x', 'p'),
#  ('c', 'r', 'a', 't'),
#  ('d', ' ', 'f', 'o'),
#  ('e', 's', ' ', ' '),
#  ('e', 'r', ' ', 'i'),
#  ('h', 't', "'", 's'),
#  (' ', 'a', ' ', 's'),
#  ('e', 's', ',', ' '),
#  ('k', 'e', ' ', 't'),
#  ('r', 'y', 'i', 'n'),
#  ('p', 'a', 'r', 't'),
#  ('u', 'g', 'h', 't'),
#  (' ', 'p', 'a', 'r'),
#  ('h', 'e', 'm', ' '),
#  ('m', 'p', ' ', 'n'),
#  ('k', 'e', 'd', ' '),
#  ('e', 'd', ' ', 'i'),
#  ('t', 'w', 'e', 'e'),
#  ('e', 's', 'n', "'"),
#  ('b', 'e', 'e', ' '),
#  ('e', 'n', 't', 's'),
#  ('t', 'u', 'r', 'e'),
#  ('a', 'f', 't', 'e'),
#  ('l', 'i', 'n', 't'),
#  (' ', 'H', 'u', 'c'),
#  ('c', 'e', ' ', 't'),
#  ('n', 'y', 'o', 'n'),
#  (' ', 's', 'u', 'p'),
#  (' ', 'f', 'i', 'n'),
#  ('n', ' ', 'o', 'n'),
#  (' ', 'v', 'o', 't'),
#  ('u', 's', 'e', ' '),
#  ('g', ' ', 'a', ' '),
#  ('o', 'o', 'k', ' '),
#  ('l', 'i', 's', 't'),
#  ('t', ' ', 'm', 'e'),
#  ('m', 'e', 's', ' '),
#  ('i', 's', ' ', 'o'),
#  ('o', 'r', ' ', 'm'),
#  (' ', '@', 'm', 'o'),
#  ('t', 'i', 'v', 'e'),
#  ('e', ' ', 'p', 'r'),
#  ('t', 'a', 'g', 'e'),
#  ('t', 'e', ' ', 't'),
#  ('b', 'i', 'o', ' '),
#  (' ', 'a', 'f', 't'),
#  ('e', 'x', 't', ' '),
#  ('T', ' ', '@', 'T'),
#  ('.', ' ', ' ', '#'),
#  ('a', 'u', 'l', ' '),
#  ('C', 'l', 'i', 'n'),
#  ('n', 'g', ' ', '#'),
#  ('f', 'a', 'c', 'e'),
#  ('e', 'a', 'l', ' '),
#  ('G', 'o', 'd', ' '),
#  (' ', 't', 'r', 'y'),
#  ('a', 'r', 't', 'y'),
#  ('n', 's', ' ', 'a'),
#  (':', ' ', 'S', 'o'),
#  ('s', ' ', 'f', 'r'),
#  ('i', 't', 'e', ' '),
#  ('h', ' ', 't', 'h'),
#  (' ', 't', 'h', 'o'),
#  ("'", 's', ' ', '#'),
#  ('s', 't', 'a', 'g'),
#  ('d', ' ', 'b', 'e'),
#  ('i', 'd', 'n', "'"),
#  ('o', 'u', ' ', 'd'),
#  (' ', 't', 'r', 'u'),
#  ('t', 'e', ',', ' '),
#  ('e', ' ', 'y', 'o'),
#  (' ', 'n', 'o', 'w'),
#  ('d', 'e', 'r', 's'),
#  ('a', 'r', 'd', ' '),
#  ('o', 'u', 's', 'l'),
#  ('u', 's', 'l', 'y'),
#  ('t', 't', 'a', 'c'),
#  ('t', 'a', 'c', 'k'),
#  ('s', 't', 'e', 'n'),
#  (' ', 's', 't', 'o'),
#  (' ', 'c', 'a', 'l'),
#  (' ', 'S', 't', 'a'),
#  ('i', 'n', 't', 'e'),
#  (' ', 'a', ' ', 'd'),
#  (' ', '#', 'G', 'o'),
#  ('n', 'k', 's', ' '),
#  ('n', 't', ' ', 'o'),
#  ('D', 'e', 'm', 'o'),
#  ('a', 't', 't', 'e'),
#  ('M', 'i', 'k', 'e'),
#  ('i', 'v', 'e', 's'),
#  ('n', 'c', 'e', 'd'),
#  ('u', 'p', 'e', 'r'),
#  ('s', 'e', 'e', ' '),
#  ('e', 'n', '.', ' '),
#  ('o', 'u', ' ', 'h'),
#  ('e', '?', ' ', '#'),
#  ('n', 'd', ' ', 'w'),
#  ('d', 'i', 'd', 'n'),
#  ('h', ' ', 'a', 'n'),
#  ('i', 'c', 'k', ' '),
#  ('T', ' ', '@', 'D'),
#  ('t', ' ', 'a', 'n'),
#  ('e', 's', ' ', 'n'),
#  (',', ' ', 'b', 'u'),
#  ('l', 'e', ':', ' '),
#  ('a', 't', 't', 'a'),
#  ('h', 't', 's', ' '),
#  ('T', ' ', '@', 'L'),
#  ('a', 't', 'e', ','),
#  ('n', 'a', 't', 'i'),
#  ('h', 't', '.', ' '),
#  (' ', 'a', ' ', 'l'),
#  ('d', ' ', 'h', 'a'),
#  ('#', 'G', 'o', 'p'),
#  ('b', 'a', 'm', 'a'),
#  ('e', 'r', 'a', 't'),
#  ('e', ' ', 'h', 'e'),
#  ('r', ' ', '&', 'a'),
#  (' ', 'p', 'o', 's'),
#  ('c', 'k', ' ', 't'),
#  ('r', 'e', 'd', ' '),
#  ('l', 'y', 'F', 'i'),
#  ('u', 'r', 'e', ' '),
#  ('s', 'h', 'o', 'w'),
#  ('h', 'e', ' ', 'r'),
#  ('e', 'm', 'i', 'n'),
#  (' ', 'g', 'i', 'v'),
#  (' ', 'S', 'o', ' '),
#  ('m', 'i', 'n', 'd'),
#  ('o', 'p', 'D', 'e'),
#  ('p', 'D', 'e', 'b'),
#  ('l', 'a', 'n', 'c'),
#  ('t', 'e', ' ', 'i'),
#  ('W', 'h', 'y', ' '),
#  ('t', 'o', 'r', ' '),
#  ('r', ' ', '#', 'G'),
#  ('t', ' ', 'r', 'i'),
#  ('g', ' ', 'f', 'o'),
#  ('t', 'r', 'y', 'i'),
#  ("'", 't', ' ', 'h'),
#  ('e', 'r', 'r', 'y'),
#  ('a', 'n', 'y', 'o'),
#  ('g', 'o', 't', ' '),
#  ('e', ' ', 'q', 'u'),
#  ('T', 'e', 'd', 'C'),
#  ('e', 'd', 'C', 'r'),
#  ('d', 'C', 'r', 'u'),
#  (' ', 'a', ' ', 'c'),
#  ('t', 'e', ' ', 'a'),
#  (' ', 'g', 'o', 't'),
#  ('e', 's', ' ', 'i'),
#  ('o', 'n', ' ', 'o'),
#  ('O', 'b', 'a', 'm'),
#  (':', ' ', 'J', 'e'),
#  ('l', 'e', 'd', ' '),
#  ('y', ' ', 'c', 'o'),
#  ('e', ' ', 'a', 's'),
#  ('O', 'X', ' ', 'N'),
#  ('e', 'r', 'm', 'a'),
#  ('w', 'h', 'e', 'r'),
#  ('s', ' ', 's', 'e'),
#  ('p', ';', ' ', 'B'),
#  ('X', ' ', 'N', 'e'),
#  ('l', 'e', 'a', 'd'),
#  (',', ' ', 't', 'h'),
#  ('a', 'l', 'a', 'n'),
#  ('l', 'l', 'i', 'n'),
#  ('.', ' ', 'Y', 'o'),
#  ('o', 'u', 'n', 'd'),
#  (' ', 'g', 'r', 'e'),
#  (':', ' ', 'h', 't'),
#  ('t', ' ', 'b', 'u'),
#  ('e', ' ', 's', 't'),
#  (' ', 'c', 'h', 'a'),
#  (' ', 's', 'e', 't'),
#  ('o', 'n', 'g', ' '),
#  ('G', 'o', 'p', 'D'),
#  ('t', 'c', 'h', ' '),
#  ('v', 'e', ' ', 'a'),
#  ('T', ' ', '@', 'j'),
#  ('o', 't', ' ', 'a'),
#  ('e', 'a', 'c', 'h'),
#  ('@', 'G', 'o', 'v'),
#  ('v', 'o', 't', 'e'),
#  ('y', ' ', 't', 'o'),
#  (' ', 'h', 'a', 'n'),
#  ('r', 'y', ' ', 'd'),
#  ('a', 'r', 'c', 'o'),
#  ('t', ' ', 'h', 'e'),
#  ('i', 'e', 'l', 'd'),
#  ('e', ' ', 'f', 'a'),
#  ('i', 'c', 'e', ' '),
#  (':', ' ', 'I', 't'),
#  ('o', 'n', ' ', 'a'),
#  ('t', '…', 'R', 'T'),
#  ('e', 'd', ' ', 'f'),
#  (',', ' ', 'I', ' '),
#  ('t', 'e', 'l', 'l'),
#  (' ', 'a', ' ', 'b'),
#  ('c', 'o', 'n', 'd'),
#  ('d', 'e', 'r', 'a'),
#  ('h', 'a', 'n', 'k'),
#  ('e', 'd', ' ', 'o'),
#  (' ', 'o', 'f', 'f'),
#  (' ', '…', 'R', 'T'),
#  ('i', 't', 't', 'e'),
#  ('e', ' ', 'o', 'r'),
#  ('r', 'r', 'y', ' '),
#  ('c', 'o', 't', 't'),
#  ('T', ' ', '@', 'J'),
#  ('u', 'g', 'h', ' '),
#  ('F', 'a', 'i', 'r'),
#  ('u', 'p', 'p', 'o'),
#  ('s', ' ', ' ', '#'),
#  ('t', 'i', 'a', 'l'),
#  ('r', 'e', 'a', 'k'),
#  ('n', 'e', 'r', ' '),
#  ("'", 't', ' ', 'l'),
#  ('e', 'a', 'd', ' '),
#  ('J', 'o', 'h', 'n'),
#  ('y', ' ', 'd', 'o'),
#  (' ', 'm', 'o', 'n'),
#  ('m', 'o', 'n', 'a'),
#  ('n', 't', 'i', 'a'),
#  ('T', ' ', '@', 'B'),
#  (' ', 'r', 'e', 's'),
#  (' ', 'l', 'i', 's'),
#  ('o', 'n', 's', 'e'),
#  (' ', 'T', 'h', 'i'),
#  (' ', 'b', 'a', 'n'),
#  ('y', ' ', 'o', 'f'),
#  ('e', 's', ' ', 'f'),
#  ('t', 'e', 'r', 's'),
#  ('e', 'd', '"', ' '),
#  ('p', 'p', 'o', 'r'),
#  ('t', ' ', 'b', 'e'),
#  ('o', 'n', 'e', 'y'),
#  ('r', 'e', 's', 's'),
#  ('a', 't', 'e', ':'),
#  ('S', 't', 'a', 't'),
#  (' ', 'I', 's', ' '),
#  ('e', ' ', 't', 'r'),
#  ('c', 'e', ' ', 'i'),
#  ('t', 'a', 'n', 'd'),
#  ('l', 'e', 'a', 'r'),
#  ('e', 'y', ' ', 'c')]
